# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'Assignments',
#  'coding_book_answers',
#  'contact.csv',
#  'hangman_art.py',
#  'leo.py',
#  'MangaOrganizer.py',
#  'names_and_scores.csv',
#  'notes.py',
#  'notes10.py',
#  'notes11.py',
#  'notes12.py',
#  'notes2.py',
#  'notes3.py',
#  'notes4.py',
#  'notes5.py',
#  'notes6.py',
#  'notes7.py',
#  'notes8.py',
#  'notes9.py',
#  'packt_python',
#  'password_project',
#  'test.csv',
#  'test.txt',
#  'total.txt',
#  'Untitled.ipynb',
#  '__pycache__']

# %%
import pandas

# %%
df1=pandas.read_csv("contact.csv")
df1
# Out:
#      Isabel   Aguillon   14114 Wetmore Bend    78247   San Antonio   Texas  \
# 0  Leonardo   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
# 1    Livier   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
# 2  Caroline      Ellis                  NaN      NaN   San Antonio   Texas
# 3       Kei      Nagai                  NaN      NaN         Tokyo   Japan
# 4     Monch   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
#
#     chavelina0105@gmail.com    2107250262
# 0         elweros@gmail.com  2.107442e+09
# 1   livieralvarez@gmail.com  2.107256e+09
# 2  cellis3259@stu.neisd.net  2.102753e+09
# 3                       NaN           NaN
# 4  lilmunchinator@gmail.com  2.107605e+09

# %%
df2=pandas.read_csv("contact.csv", header=None)
df2
# Out:
#           0          1                    2        3             4       5  \
# 0    Isabel   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
# 1  Leonardo   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
# 2    Livier   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
# 3  Caroline      Ellis                  NaN      NaN   San Antonio   Texas
# 4       Kei      Nagai                  NaN      NaN         Tokyo   Japan
# 5     Monch   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
#
#                           6             7
# 0   chavelina0105@gmail.com  2.107250e+09
# 1         elweros@gmail.com  2.107442e+09
# 2   livieralvarez@gmail.com  2.107256e+09
# 3  cellis3259@stu.neisd.net  2.102753e+09
# 4                       NaN           NaN
# 5  lilmunchinator@gmail.com  2.107605e+09

# %%
df2.columns = ["Name", "Last Name", "Address", "Zip Code", "City", "State", "Email", "Phone Number"]
df2
# Out:
#        Name  Last Name              Address  Zip Code          City   State  \
# 0    Isabel   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 1  Leonardo   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 2    Livier   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 3  Caroline      Ellis                  NaN       NaN   San Antonio   Texas
# 4       Kei      Nagai                  NaN       NaN         Tokyo   Japan
# 5     Monch   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
#
#                       Email  Phone Number
# 0   chavelina0105@gmail.com  2.107250e+09
# 1         elweros@gmail.com  2.107442e+09
# 2   livieralvarez@gmail.com  2.107256e+09
# 3  cellis3259@stu.neisd.net  2.102753e+09
# 4                       NaN           NaN
# 5  lilmunchinator@gmail.com  2.107605e+09

# %%
df2.set_index("Name", inplace=True, drop=False)
df2
# Out:
#               Name  Last Name              Address  Zip Code          City  \
# Name
# Isabel      Isabel   Aguillon   14114 Wetmore Bend   78247.0   San Antonio
# Leonardo  Leonardo   Aguillon   14114 Wetmore Bend   78247.0   San Antonio
# Livier      Livier   Aguillon   14114 Wetmore Bend   78247.0   San Antonio
# Caroline  Caroline      Ellis                  NaN       NaN   San Antonio
# Kei            Kei      Nagai                  NaN       NaN         Tokyo
# Monch        Monch   Aguillon   14114 Wetmore Bend   78247.0   San Antonio
#
#            State                     Email  Phone Number
# Name
# Isabel     Texas   chavelina0105@gmail.com  2.107250e+09
# Leonardo   Texas         elweros@gmail.com  2.107442e+09
# Livier     Texas   livieralvarez@gmail.com  2.107256e+09
# Caroline   Texas  cellis3259@stu.neisd.net  2.102753e+09
# Kei        Japan                       NaN           NaN
# Monch      Texas  lilmunchinator@gmail.com  2.107605e+09

# %%
df3 = df2.loc["Isabel":"Caroline", "Last Name":"Address"]
df3
# Out:
# Empty DataFrame
# Columns: [Last Name, Address]
# Index: []

# %%
df2
# Out:
#        Name  Last Name              Address  Zip Code          City   State  \
# 0    Isabel   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 1  Leonardo   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 2    Livier   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 3  Caroline      Ellis                  NaN       NaN   San Antonio   Texas
# 4       Kei      Nagai                  NaN       NaN         Tokyo   Japan
# 5     Monch   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
#
#                       Email  Phone Number
# 0   chavelina0105@gmail.com  2.107250e+09
# 1         elweros@gmail.com  2.107442e+09
# 2   livieralvarez@gmail.com  2.107256e+09
# 3  cellis3259@stu.neisd.net  2.102753e+09
# 4                       NaN           NaN
# 5  lilmunchinator@gmail.com  2.107605e+09

# %%
df2.loc[:, "Name"]
# Out:
# 0      Isabel
# 1    Leonardo
# 2      Livier
# 3    Caroline
# 4         Kei
# 5       Monch
# Name: Name, dtype: object

# %%
df3 = list(df2.loc[:, "Last Name"])
df3
# Out:
# [' Aguillon', ' Aguillon', ' Aguillon', 'Ellis', 'Nagai', 'Aguillon']

# %%
df2
# Out:
#        Name  Last Name              Address  Zip Code          City   State  \
# 0    Isabel   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 1  Leonardo   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 2    Livier   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 3  Caroline      Ellis                  NaN       NaN   San Antonio   Texas
# 4       Kei      Nagai                  NaN       NaN         Tokyo   Japan
# 5     Monch   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
#
#                       Email  Phone Number
# 0   chavelina0105@gmail.com  2.107250e+09
# 1         elweros@gmail.com  2.107442e+09
# 2   livieralvarez@gmail.com  2.107256e+09
# 3  cellis3259@stu.neisd.net  2.102753e+09
# 4                       NaN           NaN
# 5  lilmunchinator@gmail.com  2.107605e+09

# %%
df3 = df2.iloc[1:3, 1:3]
df3
# Out:
#    Last Name              Address
# 1   Aguillon   14114 Wetmore Bend
# 2   Aguillon   14114 Wetmore Bend

# %%
df4 = df2.iloc[0:3, 0:3]
df4
# Out:
#        Name  Last Name              Address
# 0    Isabel   Aguillon   14114 Wetmore Bend
# 1  Leonardo   Aguillon   14114 Wetmore Bend
# 2    Livier   Aguillon   14114 Wetmore Bend

# %%
df5 = df2.iloc[:, 0:4]
df5
# Out:
#        Name  Last Name              Address  Zip Code
# 0    Isabel   Aguillon   14114 Wetmore Bend   78247.0
# 1  Leonardo   Aguillon   14114 Wetmore Bend   78247.0
# 2    Livier   Aguillon   14114 Wetmore Bend   78247.0
# 3  Caroline      Ellis                  NaN       NaN
# 4       Kei      Nagai                  NaN       NaN
# 5     Monch   Aguillon   14114 Wetmore Bend   78247.0

# %%
df6 = df2.iloc[3, 0:2]
df6
# Out:
# Name         Caroline
# Last Name       Ellis
# Name: 3, dtype: object

# %%
df2
# Out:
#        Name  Last Name              Address  Zip Code          City   State  \
# 0    Isabel   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 1  Leonardo   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 2    Livier   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 3  Caroline      Ellis                  NaN       NaN   San Antonio   Texas
# 4       Kei      Nagai                  NaN       NaN         Tokyo   Japan
# 5     Monch   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
#
#                       Email  Phone Number
# 0   chavelina0105@gmail.com  2.107250e+09
# 1         elweros@gmail.com  2.107442e+09
# 2   livieralvarez@gmail.com  2.107256e+09
# 3  cellis3259@stu.neisd.net  2.102753e+09
# 4                       NaN           NaN
# 5  lilmunchinator@gmail.com  2.107605e+09

# %%
df2.shape
# Out:
# (6, 8)

# %%
df7=df2["Country"]=["United States", "United States", "United States", "United States", "Japan", "United States"]
df7
# Out:
# ['United States',
#  'United States',
#  'United States',
#  'United States',
#  'Japan',
#  'United States']

# %%
df2
# Out:
#        Name  Last Name              Address  Zip Code          City   State  \
# 0    Isabel   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 1  Leonardo   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 2    Livier   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# 3  Caroline      Ellis                  NaN       NaN   San Antonio   Texas
# 4       Kei      Nagai                  NaN       NaN         Tokyo   Japan
# 5     Monch   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
#
#                       Email  Phone Number        Country
# 0   chavelina0105@gmail.com  2.107250e+09  United States
# 1         elweros@gmail.com  2.107442e+09  United States
# 2   livieralvarez@gmail.com  2.107256e+09  United States
# 3  cellis3259@stu.neisd.net  2.102753e+09  United States
# 4                       NaN           NaN          Japan
# 5  lilmunchinator@gmail.com  2.107605e+09  United States

# %%
df2.shape
# Out:
# (6, 9)

# %%
df_t=df2.T
df_t
# Out:
#                                      0                    1  \
# Name                            Isabel             Leonardo
# Last Name                     Aguillon             Aguillon
# Address             14114 Wetmore Bend   14114 Wetmore Bend
# Zip Code                       78247.0              78247.0
# City                       San Antonio          San Antonio
# State                            Texas                Texas
# Email          chavelina0105@gmail.com    elweros@gmail.com
# Phone Number              2107250262.0         2107442060.0
# Country                  United States        United States
#
#                                      2                         3      4  \
# Name                            Livier                  Caroline    Kei
# Last Name                     Aguillon                     Ellis  Nagai
# Address             14114 Wetmore Bend                       NaN    NaN
# Zip Code                       78247.0                       NaN    NaN
# ...

# %%
df8=df_t.T
df8
# Out:
#        Name  Last Name              Address Zip Code          City   State  \
# 0    Isabel   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
# 1  Leonardo   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
# 2    Livier   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
# 3  Caroline      Ellis                  NaN      NaN   San Antonio   Texas
# 4       Kei      Nagai                  NaN      NaN         Tokyo   Japan
# 5     Monch   Aguillon   14114 Wetmore Bend  78247.0   San Antonio   Texas
#
#                       Email  Phone Number        Country
# 0   chavelina0105@gmail.com  2107250262.0  United States
# 1         elweros@gmail.com  2107442060.0  United States
# 2   livieralvarez@gmail.com  2107255842.0  United States
# 3  cellis3259@stu.neisd.net  2102752657.0  United States
# 4                       NaN           NaN          Japan
# 5  lilmunchinator@gmail.com  2107605469.0  United States

# %%
df2.set_index("Name", inplace=True, drop=False)
df2
# Out:
#               Name  Last Name              Address  Zip Code          City  \
# Name
# Isabel      Isabel   Aguillon   14114 Wetmore Bend   78247.0   San Antonio
# Leonardo  Leonardo   Aguillon   14114 Wetmore Bend   78247.0   San Antonio
# Livier      Livier   Aguillon   14114 Wetmore Bend   78247.0   San Antonio
# Caroline  Caroline      Ellis                  NaN       NaN   San Antonio
# Kei            Kei      Nagai                  NaN       NaN         Tokyo
# Monch        Monch   Aguillon   14114 Wetmore Bend   78247.0   San Antonio
#
#            State                     Email  Phone Number        Country
# Name
# Isabel     Texas   chavelina0105@gmail.com  2.107250e+09  United States
# Leonardo   Texas         elweros@gmail.com  2.107442e+09  United States
# Livier     Texas   livieralvarez@gmail.com  2.107256e+09  United States
# Caroline   Texas  cellis3259@stu.neisd.net  2.102753e+09  United States
# ...

# %%
df2.loc[:, "Last Name"]
# Out:
# Name
# Isabel       Aguillon
# Leonardo     Aguillon
# Livier       Aguillon
# Caroline        Ellis
# Kei             Nagai
# Monch        Aguillon
# Name: Last Name, dtype: object

# %%
df2.loc["Isabel":"Caroline", "Last Name":"Email"]
# Out:
#           Last Name              Address  Zip Code          City   State  \
# Name
# Isabel     Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# Leonardo   Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# Livier     Aguillon   14114 Wetmore Bend   78247.0   San Antonio   Texas
# Caroline      Ellis                  NaN       NaN   San Antonio   Texas
#
#                              Email
# Name
# Isabel     chavelina0105@gmail.com
# Leonardo         elweros@gmail.com
# Livier     livieralvarez@gmail.com
# Caroline  cellis3259@stu.neisd.net
